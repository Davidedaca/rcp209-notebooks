# %% [markdown]
# # VIII - Perceptron multi-couches

# %% [markdown]
# ## Supports de cours
#
# - [VIII.1 - Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [VIII.2 - Travaux pratiques](practical.ipynb)
