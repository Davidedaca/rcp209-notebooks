# %% [markdown]
# # IX - Optimisation

# %% [markdown]
# ## Supports de cours
#
# - [IX.1 - Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [XI.2 - Travaux pratiques](practical.ipynb)
