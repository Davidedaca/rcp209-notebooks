# %% [markdown]
# # X - Réseaux convolutifs

# %% [markdown]
# ## Supports de cours
#
# - [X.1 - Cours](session10_course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [X.2 - Travaux pratiques](session10_practical.ipynb)
