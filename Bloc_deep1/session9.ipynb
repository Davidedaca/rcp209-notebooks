# %% [markdown]
# # IX - Optimisation

# %% [markdown]
# ## Supports de cours
#
# - [IX.1 - Cours](session9_course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [XI.2 - Travaux pratiques](session9_practical.ipynb)
