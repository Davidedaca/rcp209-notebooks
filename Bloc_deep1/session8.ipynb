# %% [markdown]
# # VIII - Perceptron multi-couches

# %% [markdown]
# ## Supports de cours
#
# - [VIII.1 - Cours](session8_course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [VIII.2 - Travaux pratiques](session8_practical.ipynb)
