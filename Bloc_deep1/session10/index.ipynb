# %% [markdown]
# # X - Réseaux convolutifs

# %% [markdown]
# ## Supports de cours
#
# - [X.1 - Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [X.2 - Travaux pratiques](practical.ipynb)
