# %% [markdown]
# # XI - CNN modernes

# %% [markdown]
# ## Supports de cours
#
# - [XI.1 - Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [XI.2 - Travaux pratiques](practical.ipynb)
