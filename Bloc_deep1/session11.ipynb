# %% [markdown]
# # XI - CNN modernes

# %% [markdown]
# ## Supports de cours
#
# - [XI.1 - Cours](session11_course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [XI.2 - Travaux pratiques](session11_practical.ipynb)
