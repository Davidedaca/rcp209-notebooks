# %% [markdown]
# # IV - Forêts aléatoires

# %% [markdown]
# ## Supports de cours
#
# - [IV.1 Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [IV.2 Travaux pratiques](practical.ipynb)
