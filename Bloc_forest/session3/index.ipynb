# %% [markdown]
# # III - Arbres de décision

# %% [markdown]
# ## Supports de cours
#
# - [III.1 Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [III.2 Travaux pratiques](practical.ipynb)
