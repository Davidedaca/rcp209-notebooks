# %% [markdown]
# # III - Arbres de décision

# %% [markdown]
# ## Supports de cours
#
# - [III.1 Cours](session3_course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [III.2 Travaux pratiques](session3_practical.ipynb)
