# %% [markdown]
# # IV - Forêts aléatoires

# %% [markdown]
# ## Supports de cours
#
# - [IV.1 Cours](session4_course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [IV.2 Travaux pratiques](session4_practical.ipynb)
