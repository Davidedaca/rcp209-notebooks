# %% [markdown]
# # XII - Réseaux récurrents

# %% [markdown]
# ## Supports de cours
#
# - [XII.1 - Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [XII.2 - Travaux pratiques - Prédiction de séries temporelles](practical.ipynb)
