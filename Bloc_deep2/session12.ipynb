# %% [markdown]
# # XII - Réseaux récurrents

# %% [markdown]
# ## Supports de cours
#
# - [XII.1 - Cours](session12_course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [XII.2 - Travaux pratiques - Prédiction de séries temporelles](session12_practical.ipynb)
