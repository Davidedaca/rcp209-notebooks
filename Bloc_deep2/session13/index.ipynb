# %% [markdown]
# # XIII - Transformeurs

# %% [markdown]
# ## Supports de cours
#
# - [XIII.1 - Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [XIII.2 - Travaux pratiques - Prédiction de séries temporelles avec un Transformer](practical.ipynb)
