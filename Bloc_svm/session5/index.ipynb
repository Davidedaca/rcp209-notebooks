# %% [markdown]
# # V - SVM Linéaires

# %% [markdown]
# ## Supports de cours
#
# - [V.1 - Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [V.2 - Travaux pratiques](practical.ipynb)
