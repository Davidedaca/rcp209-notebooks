# %% [markdown]
# # V - SVM Linéaires

# %% [markdown]
# ## Supports de cours
#
# - [V.1 - Cours](session5_course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [V.2 - Travaux pratiques](session5_practical.ipynb)
