# %% [markdown]
# # VI - Méthodes à noyaux

# %% [markdown]
# ## Supports de cours
#
# - [VI.1 Cours](session6_course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [VI.2 - Travaux pratiques](session6_practical.ipynb)
