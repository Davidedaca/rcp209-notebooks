# %% [markdown]
# # VII - Algorithmes à noyaux

# %% [markdown]
# ## Supports de cours
#
# - [VII.1 - Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [VII.2 - Travaux pratiques](practical.ipynb)
