# %% [markdown]
# # VI - Méthodes à noyaux

# %% [markdown]
# ## Supports de cours
#
# - [VI.1 Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [VI.2 - Travaux pratiques](practical.ipynb)
