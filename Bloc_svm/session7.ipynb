# %% [markdown]
# # VII - Algorithmes à noyaux

# %% [markdown]
# ## Supports de cours
#
# - [VII.1 - Cours](session7_course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [VII.2 - Travaux pratiques](session7_practical.ipynb)
