# %% [markdown]
# # I - Apprentissage supervisé

# %% [markdown]
# ## Supports de cours
#
# - [I.1 - Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [I.2 - Travaux pratiques](practical.ipynb)
