# %% [markdown]
# # I - Apprentissage supervisé

# %% [markdown]
# ## Supports de cours
#
# - [I.1 - Cours](session1_course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [I.2 - Travaux pratiques](session1_practical.ipynb)
