# %% [markdown]
# # II - Evaluation de modèles

# %% [markdown]
# ## Supports de cours
#
# - [II.1 - Cours](session2_course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [II.2 - Travaux pratiques](session2_practical.ipynb)
