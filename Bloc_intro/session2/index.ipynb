# %% [markdown]
# # II - Evaluation de modèles

# %% [markdown]
# ## Supports de cours
#
# - [II.1 - Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [II.2 - Travaux pratiques](practical.ipynb)
