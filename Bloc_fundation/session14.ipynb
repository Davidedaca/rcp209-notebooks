# %% [markdown]
# # VIV - Apprentissage auto-supervisé

# %% [markdown]
# ## Supports de cours
#
# - [XIV.1 - Cours](session14_course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [XIV.2 - Travaux pratiques](session14_practical.ipynb)
