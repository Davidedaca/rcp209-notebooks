# %% [markdown]
# # VIV - Apprentissage auto-supervisé

# %% [markdown]
# ## Supports de cours
#
# - [XIV.1 - Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [XIV.2 - Travaux pratiques](practical.ipynb)
