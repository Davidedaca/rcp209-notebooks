# %% [markdown]
# # XV - Modèles de fondation

# %% [markdown]
# ## Supports de cours
#
# - [XV.1 - Cours](course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [XV.2 - Travaux pratiques](practical.ipynb)
