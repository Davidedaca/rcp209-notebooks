# %% [markdown]
# # XV - Modèles de fondation

# %% [markdown]
# ## Supports de cours
#
# - [XV.1 - Cours](session15_course.ipynb)

# %% [markdown]
# ## Travaux pratiques
#
# - [XV.2 - Travaux pratiques](session15_practical.ipynb)
